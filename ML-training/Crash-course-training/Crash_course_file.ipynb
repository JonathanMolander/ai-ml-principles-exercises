# %% [markdown]
# <a href="https://colab.research.google.com/github/JonathanMolander/ai-ml-principles-exercises/blob/main/ML-training/Crash-course-training/Crash_course_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world")
# Out:
# Hello world

# %%
print("Hello again!")
# Out:
# Hello again!

# %%
# !wget https://images.immediate.co.uk/production/volatile/sites/4/2021/08/mountains-7ddde89.jpg
# Out:
# --2022-12-01 13:33:53--  https://images.immediate.co.uk/production/volatile/sites/4/2021/08/mountains-7ddde89.jpg
# Resolving images.immediate.co.uk (images.immediate.co.uk)... 151.101.2.137, 151.101.66.137, 151.101.130.137, ...
# Connecting to images.immediate.co.uk (images.immediate.co.uk)|151.101.2.137|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 56050 (55K) [image/jpeg]
# Saving to: ‘mountains-7ddde89.jpg’
#
# mountains-7ddde89.j 100%[===================>]  54.74K  --.-KB/s    in 0.007s
#
# 2022-12-01 13:33:53 (8.05 MB/s) - ‘mountains-7ddde89.jpg’ saved [56050/56050]

# %%
# !ls
# Out:
# mountains-7ddde89.jpg  sample_data

# %%
from PIL import Image

# %%
pillow_image = Image.open("mountains-7ddde89.jpg")
pillow_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x511 at 0x7F26B06989D0>

# %%
import numpy as np

np_image = np.array(pillow_image)
h, w, ch = np_image.shape

# %%
Image.fromarray(np_image, "RGB")
# Out:
# <PIL.Image.Image image mode=RGB size=1200x511 at 0x7F26A0BC2040>

# %%
no_blue = np_image[np_image[:, :, 2] > 127] = 255  # Makes all the blue disappear
no_blue_image = Image.fromarray(np_image, "RGB")
no_blue_image
# Out:
# <PIL.Image.Image image mode=RGB size=1200x511 at 0x7F26A0B9BD00>

# %%
blue_ch = np_image[:, :, 2]
blue_image = Image.fromarray(blue_ch, "L")
blue_image.resize((w//4, h//4))
# Out:
# <PIL.Image.Image image mode=L size=300x127 at 0x7F26A0BC28B0>
